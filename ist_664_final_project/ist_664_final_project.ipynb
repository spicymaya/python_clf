# %% [markdown]
# ### Steps:
# - 1. tokenize it and choose whether to do further pre-processing or filtering.
# - 2. The second step is to produce the features in the notation of the NLTK.
#     - a. write feature functions
#     - b. start with the “bag-of-words” features where you collect all the words in the corpus and select some number of most frequent words to be the word features.
# - 3. use the NLTK Naïve Bayes classifier to train and test a classifier on your feature sets. You should use cross-validation to obtain precision, recall and F-measure scores.
#     - a. you can choose to produce the features as a csv file and use sklearn to train and test a classifier, using cross-validation scores.
# - 4. For a base level completion of experiments, carry out at least several experiments where you
# use two different sets of features and compare the results.
# EXAMPLE: Take the
# unigram word features as a baseline and see if the features you designed improve the accuracy of
# the classification.
#
# Some of the types of experiments:
# - filter by stopwords or other pre-processing methods
# - representing negation (if using twitter data, note the difference in tokenization)
# - using a sentiment lexicon with scores or counts: Subjectivity
# - different sizes of vocabularies
#
# - POS tag features
# - 5. define at least one “new” feature function not given in class. Also you should try to
# combine some of the earlier features, e.g. to use unigrams, bigrams, POS tag counts, and
# sentiment word counts all in one feature set. Examples of new features:
#     - Use the LIWC sentiment lexicon
#     - combine the use of sentiment lexicons
#     - use a different representation of negation, for example, carrying the scope of the negation
# work over to the next punctuation
# - 6. Do something from this list:
# using Sklearn classifiers with features produced in NLTK.
# - • using an additional type of lexicon besides Subjectivity or LIWC
# - • in addition to using cross-validation on the training set, train the classifier on the entire
# training set and test it on a separately available test set (only the SemEval data has these)
# o note that you must save the vocabulary from the training set and use the same for
# creating feature sets for the test data
#
# - • implement additional features
#     - in the email dataset, use word frequency or tfidf scores as the values of the word
# features, instead of Boolean values
#     - use POS tagging from the ARK on Twitter
#     - twitter emoticons or other features based on internet usage or informal text, such
# as repeated letters, or all caps words

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# print all outputs, not just the last one
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd
import sklearn as sk
from nltk import *
import re
import numpy as np
import random
import matplotlib.pyplot as plt
from nltk import sent_tokenize
from prettytable import PrettyTable

# %%
test = pd.read_table('./sentiment-analysis-on-movie-reviews/test.tsv')
train = pd.read_table('./sentiment-analysis-on-movie-reviews/train.tsv')

# %%
# drop sendenceId dupes
train.drop_duplicates(subset="SentenceId", keep="first", inplace=True)

# %% [markdown]
# ### Add more columns to analyze the data

# %% [markdown]
# Clone train dataframe and add additional columns

# %%
train_additional_cols = pd.DataFrame(train)

train_additional_cols["word_tokens"] = np.nan
train_additional_cols["phrase_length"] = np.nan
train_additional_cols["POS_tags"] = np.nan

# %% [markdown]
# Remove all rows where Phrase is 1 char long

# %%
train_additional_cols[:76]
# Out:
#       PhraseId  SentenceId                                             Phrase  \
# 0            1           1  A series of escapades demonstrating the adage ...
# 63          64           2  This quiet , introspective and entertaining in...
# 81          82           3  Even fans of Ismail Merchant 's work , I suspe...
# 116        117           4  A positively thrilling combination of ethnogra...
# 156        157           5  Aggressive self-glorification and a manipulati...
# ...        ...         ...                                                ...
# 1937      1938          72  -LRB- Scherfig -RRB- has made a movie that wil...
# 1965      1966          73             -LRB- An -RRB- absorbing documentary .
# 1972      1973          74  Reeks of rot and hack work from start to finish .
# 1983      1984          75  Plays like a series of vignettes -- clips of a...
# 2005      2006          76
#
#       Sentiment  word_tokens  phrase_length  POS_tags
# 0             1          NaN            NaN       NaN
# 63            4          NaN            NaN       NaN
# 81            1          NaN            NaN       NaN
# 116           3          NaN            NaN       NaN
# 156           1          NaN            NaN       NaN
# ...         ...          ...            ...       ...
# 1937          3          NaN            NaN       NaN
# 1965          3          NaN            NaN       NaN
# 1972          2          NaN            NaN       NaN
# 1983          1          NaN            NaN       NaN
# 2005          1          NaN            NaN       NaN
#
# [76 rows x 7 columns]

# %%
for i, phrase in enumerate(train_additional_cols['Phrase']):
    # just a single letter or space
    if len(phrase)==1:
        train_additional_cols.drop(train_additional_cols.index[i], inplace=True)

# %%
train_additional_cols.reset_index(drop=True, inplace=True)

# %%
# stop words from NLTK
nltk_stop_words = corpus.stopwords.words('english')

# %%
# function that takes a word and returns true if it consists only of non-alphabetic characters 
def alpha_filter(w):
  # pattern to match word of non-alphabetical characters
  pattern = re.compile('^[^a-z]+$')
  if pattern.match(w):
    return True
  else:
    return False

# %%
# removes stopwords and puctuation from text provided
def remove_stopwords_and_punct(sentence):
    for word in sentence:
        if word in nltk_stop_words:
            if alpha_filter(word):
                sentense = sentence.remove(word)
    return sentence

# %% [markdown]
# This will loop will:
# - 1. tokenize
# - 2. set to lowercase
# - 3. removes puctuation and stop words

# %%
 train_additional_cols_num_rows = len(train_additional_cols.index)

# %%
for index in range(train_additional_cols_num_rows):
    phrase = train_additional_cols['Phrase'][index]
    sent_token = sent_tokenize(phrase.lower())
#     sent_token comes as a list, we need a string
    word_token = word_tokenize(sent_token[0])
    word_token_clean = remove_stopwords_and_punct(word_token)
    train_additional_cols["word_tokens"][index] = word_token_clean
    train_additional_cols["phrase_length"][index] = len(phrase)

# %%
# check data to make sure tokens match sentences at the beginning and end
train_additional_cols.head()
train_additional_cols.tail()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1        64           2  This quiet , introspective and entertaining in...
# 2        82           3  Even fans of Ismail Merchant 's work , I suspe...
# 3       117           4  A positively thrilling combination of ethnogra...
# 4       157           5  Aggressive self-glorification and a manipulati...
#
#    Sentiment                                        word_tokens  \
# 0          1  [a, series, of, escapades, demonstrating, the,...
# 1          4  [this, quiet, ,, introspective, and, entertain...
# 2          1  [even, fans, of, ismail, merchant, 's, work, ,...
# 3          3  [a, positively, thrilling, combination, of, et...
# 4          1  [aggressive, self-glorification, and, a, manip...
#
#    phrase_length  POS_tags
# 0          188.0       NaN
# 1           74.0       NaN
# 2          100.0       NaN
# 3          152.0       NaN
# 4           60.0       NaN
#       PhraseId  SentenceId                                             Phrase  \
# 8522    155985        8540  ... either you 're willing to go with this cla...
# 8523    155998        8541  Despite these annoyances , the capable Claybur...
# 8524    156022        8542  -LRB- Tries -RRB- to parody a genre that 's al...
# 8525    156032        8543  The movie 's downfall is to substitute plot fo...
# 8526    156040        8544  The film is darkly atmospheric , with Herrmann...
#
#       Sentiment                                        word_tokens  \
# 8522          2  [..., either, you, 're, willing, to, go, with,...
# 8523          2  [despite, these, annoyances, ,, the, capable, ...
# 8524          1  [-lrb-, tries, -rrb-, to, parody, a, genre, th...
# 8525          1  [the, movie, 's, downfall, is, to, substitute,...
# 8526          2  [the, film, is, darkly, atmospheric, ,, with, ...
#
#       phrase_length  POS_tags
# 8522           82.0       NaN
# 8523          152.0       NaN
# 8524           81.0       NaN
# 8525           61.0       NaN
# 8526          137.0       NaN

# %% [markdown]
# #### POS tagging, grammar rules phrase extraction

# %% [markdown]
# This loop will tag each list of tokens

# %%
for index, token_list in enumerate(train_additional_cols['word_tokens']):
    pos_tokens = pos_tag(token_list)
    train_additional_cols["POS_tags"][index] = pos_tokens

# %%
# check tags at the beginning and end
train_additional_cols.head()
train_additional_cols.tail()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1        64           2  This quiet , introspective and entertaining in...
# 2        82           3  Even fans of Ismail Merchant 's work , I suspe...
# 3       117           4  A positively thrilling combination of ethnogra...
# 4       157           5  Aggressive self-glorification and a manipulati...
#
#    Sentiment                                        word_tokens  \
# 0          1  [a, series, of, escapades, demonstrating, the,...
# 1          4  [this, quiet, ,, introspective, and, entertain...
# 2          1  [even, fans, of, ismail, merchant, 's, work, ,...
# 3          3  [a, positively, thrilling, combination, of, et...
# 4          1  [aggressive, self-glorification, and, a, manip...
#
#    phrase_length                                           POS_tags
# 0          188.0  [(a, DT), (series, NN), (of, IN), (escapades, ...
# 1           74.0  [(this, DT), (quiet, JJ), (,, ,), (introspecti...
# 2          100.0  [(even, RB), (fans, NNS), (of, IN), (ismail, J...
# 3          152.0  [(a, DT), (positively, RB), (thrilling, VBG), ...
# 4           60.0  [(aggressive, JJ), (self-glorification, NN), (...
#       PhraseId  SentenceId                                             Phrase  \
# 8522    155985        8540  ... either you 're willing to go with this cla...
# 8523    155998        8541  Despite these annoyances , the capable Claybur...
# 8524    156022        8542  -LRB- Tries -RRB- to parody a genre that 's al...
# 8525    156032        8543  The movie 's downfall is to substitute plot fo...
# 8526    156040        8544  The film is darkly atmospheric , with Herrmann...
#
#       Sentiment                                        word_tokens  \
# 8522          2  [..., either, you, 're, willing, to, go, with,...
# 8523          2  [despite, these, annoyances, ,, the, capable, ...
# 8524          1  [-lrb-, tries, -rrb-, to, parody, a, genre, th...
# 8525          1  [the, movie, 's, downfall, is, to, substitute,...
# 8526          2  [the, film, is, darkly, atmospheric, ,, with, ...
#
#       phrase_length                                           POS_tags
# 8522           82.0  [(..., :), (either, CC), (you, PRP), ('re, VBP...
# 8523          152.0  [(despite, IN), (these, DT), (annoyances, NNS)...
# 8524           81.0  [(-lrb-, JJ), (tries, NNS), (-rrb-, VBP), (to,...
# 8525           61.0  [(the, DT), (movie, NN), ('s, POS), (downfall,...
# 8526          137.0  [(the, DT), (film, NN), (is, VBZ), (darkly, JJ...

# %%
# an ADJPH chunk should be formed whenever the chunker finds adverb (RB) followed by an adjective (JJ).
grammar_adjph = "ADJPH: {<RB.?>+<JJ.?>}"
# an ADVPH chunk should be formed whenever the chunker finds 2 consecutive adverbs ('RB')
grammar_advph = "ADVPH: {<RB>+<RB>}"
# an VBPH chunk should be formed whenever the chunker finds verb (VB) followed by a noun (NN).
grammar_vbph = "VBPH: {<VB.?>+<NN.?>}"
# an NPH chunk should be formed whenever the chunker finds a determiner (DT) followed by a noun (NN). We simply choose to define noun phrase as determiner followed by a noun of any kind.
grammar_nph = "NPH: {<DT>+<NN.?>}"

# %%
# function toimport the nltk parser to process each sentence
def create_chunk_parser(grammar_rules):
    return RegexpParser(grammar_rules)

# %% [markdown]
# This function will do the following:
# - parse text based on parser provided
# - get the actual phrase
# - calculate frequency for most_common phrases (log only, we can add a return value)
# - show the length of phrases sentences (log only)

# %%
def parse_phrases(sent, chunk_parser, label):
    tags = []
    phrases = []

    if len(sent) > 0:
#         print('sent', sent)
        tree = chunk_parser.parse(sent)
        for subtree in tree.subtrees():
            if subtree.label() == label:
                tags.append(subtree)
    # Visualizing the actual phrase
    for sent in tags:
        temp = ''
        for w, t in sent:
            temp += w+ ' '    
        phrases.append(temp)
    print('phrases: ', phrases)
    # top 10 phrases
    freq = FreqDist(phrases)
    print('Top phrases by frequency: ')
    for word, freq in freq.most_common(10):
        print(word, freq)
    print("Length of {label} phrase sentences: ".format(label=label), len(tags))
    return phrases

# %% [markdown]
# ##### Create parsers and parse the texts using the rules/parsers defined

# %%
adjph_parser = create_chunk_parser(grammar_adjph)
advph_parser = create_chunk_parser(grammar_advph)
vbph_parser = create_chunk_parser(grammar_vbph)
nph_parser = create_chunk_parser(grammar_nph)

# %% [markdown]
# Add more cols for grammar parser results

# %%
train_additional_cols["adjph"] = np.nan
train_additional_cols["advph"] = np.nan
train_additional_cols["vbph"] = np.nan
train_additional_cols["nph"] = np.nan

# %%
for index in range(train_additional_cols_num_rows):
    pos_tree = train_additional_cols['POS_tags'][index]
    if parse_phrases(pos_tree, adjph_parser, "ADJPH"):
        train_additional_cols["adjph"][index] = parse_phrases(pos_tree, adjph_parser, "ADJPH")
    else:
        train_additional_cols["adjph"][index] = 'no ADJPH phrases detected'
# Out:
# phrases:  ['also good ']
# Top phrases by frequency:
# also good  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['also good ']
# Top phrases by frequency:
# also good  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['nearly epic ']
# Top phrases by frequency:
# nearly epic  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['nearly epic ']
# Top phrases by frequency:
# nearly epic  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['so thick ']
# Top phrases by frequency:
# so thick  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['so thick ']
# Top phrases by frequency:
# so thick  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['too hard ']
# Top phrases by frequency:
# too hard  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['too hard ']
# Top phrases by frequency:
# too hard  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['less dizzily gorgeous ']
# Top phrases by frequency:
# less dizzily gorgeous  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['less dizzily gorgeous ']
# Top phrases by frequency:
# less dizzily gorgeous  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['as inept ']
# Top phrases by frequency:
# as inept  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['as inept ']
# Top phrases by frequency:
# as inept  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['almost indecipherable ']
# Top phrases by frequency:
# almost indecipherable  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['almost indecipherable ']
# Top phrases by frequency:
# almost indecipherable  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['actually rather sweet ']
# Top phrases by frequency:
# actually rather sweet  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['actually rather sweet ']
# Top phrases by frequency:
# actually rather sweet  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['very little ']
# Top phrases by frequency:
# very little  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['very little ']
# Top phrases by frequency:
# very little  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['easily substitutable ']
# Top phrases by frequency:
# easily substitutable  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['easily substitutable ']
# Top phrases by frequency:
# easily substitutable  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['more interested ']
# Top phrases by frequency:
# more interested  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['more interested ']
# Top phrases by frequency:
# more interested  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['totally unexpected ']
# Top phrases by frequency:
# totally unexpected  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['totally unexpected ']
# Top phrases by frequency:
# totally unexpected  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['so pat ']
# Top phrases by frequency:
# so pat  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['so pat ']
# Top phrases by frequency:
# so pat  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['particularly dark ']
# Top phrases by frequency:
# particularly dark  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['particularly dark ']
# Top phrases by frequency:
# particularly dark  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['more deeply ']
# Top phrases by frequency:
# more deeply  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['more deeply ']
# Top phrases by frequency:
# more deeply  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['still good ']
# Top phrases by frequency:
# still good  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['still good ']
# Top phrases by frequency:
# still good  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['embarrassingly ham-fisted ']
# Top phrases by frequency:
# embarrassingly ham-fisted  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['embarrassingly ham-fisted ']
# Top phrases by frequency:
# embarrassingly ham-fisted  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['nearly impossible ']
# Top phrases by frequency:
# nearly impossible  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['nearly impossible ']
# Top phrases by frequency:
# nearly impossible  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['as sanguine ']
# Top phrases by frequency:
# as sanguine  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['as sanguine ']
# Top phrases by frequency:
# as sanguine  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['very funny ']
# Top phrases by frequency:
# very funny  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['very funny ']
# Top phrases by frequency:
# very funny  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['pretty good ']
# Top phrases by frequency:
# pretty good  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['pretty good ']
# Top phrases by frequency:
# pretty good  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['intoxicatingly sexy ']
# Top phrases by frequency:
# intoxicatingly sexy  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['intoxicatingly sexy ']
# Top phrases by frequency:
# intoxicatingly sexy  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['highly recommended ']
# Top phrases by frequency:
# highly recommended  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['highly recommended ']
# Top phrases by frequency:
# highly recommended  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['just as wonderful ']
# Top phrases by frequency:
# just as wonderful  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['just as wonderful ']
# Top phrases by frequency:
# just as wonderful  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['very different ', 'yet instantly recognizable ']
# Top phrases by frequency:
# very different  1
# yet instantly recognizable  1
# Length of ADJPH phrase sentences:  2
# phrases:  ['very different ', 'yet instantly recognizable ']
# Top phrases by frequency:
# very different  1
# yet instantly recognizable  1
# Length of ADJPH phrase sentences:  2
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['as comprehensible ']
# Top phrases by frequency:
# as comprehensible  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['as comprehensible ']
# Top phrases by frequency:
# as comprehensible  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['not so much ']
# Top phrases by frequency:
# not so much  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['not so much ']
# Top phrases by frequency:
# not so much  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['particularly good ']
# Top phrases by frequency:
# particularly good  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['particularly good ']
# Top phrases by frequency:
# particularly good  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['just about ready ']
# Top phrases by frequency:
# just about ready  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['just about ready ']
# Top phrases by frequency:
# just about ready  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['very stylized ']
# Top phrases by frequency:
# very stylized  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['very stylized ']
# Top phrases by frequency:
# very stylized  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['most thoughtful ']
# Top phrases by frequency:
# most thoughtful  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['most thoughtful ']
# Top phrases by frequency:
# most thoughtful  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['so consistently unimaginative ']
# Top phrases by frequency:
# so consistently unimaginative  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['so consistently unimaginative ']
# Top phrases by frequency:
# so consistently unimaginative  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['visually masterful ']
# Top phrases by frequency:
# visually masterful  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['visually masterful ']
# Top phrases by frequency:
# visually masterful  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ["n't very funny "]
# Top phrases by frequency:
# n't very funny  1
# Length of ADJPH phrase sentences:  1
# phrases:  ["n't very funny "]
# Top phrases by frequency:
# n't very funny  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['very important ']
# Top phrases by frequency:
# very important  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['very important ']
# Top phrases by frequency:
# very important  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['entirely unprepared ']
# Top phrases by frequency:
# entirely unprepared  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['entirely unprepared ']
# Top phrases by frequency:
# entirely unprepared  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['forgettably entertaining ']
# Top phrases by frequency:
# forgettably entertaining  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['forgettably entertaining ']
# Top phrases by frequency:
# forgettably entertaining  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['more potent ']
# Top phrases by frequency:
# more potent  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['more potent ']
# Top phrases by frequency:
# more potent  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['mostly unsurprising ', 'even delectable ']
# Top phrases by frequency:
# mostly unsurprising  1
# even delectable  1
# Length of ADJPH phrase sentences:  2
# phrases:  ['mostly unsurprising ', 'even delectable ']
# Top phrases by frequency:
# mostly unsurprising  1
# even delectable  1
# Length of ADJPH phrase sentences:  2
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['refreshingly natural ', 'barely clad ']
# Top phrases by frequency:
# refreshingly natural  1
# barely clad  1
# Length of ADJPH phrase sentences:  2
# phrases:  ['refreshingly natural ', 'barely clad ']
# Top phrases by frequency:
# refreshingly natural  1
# barely clad  1
# Length of ADJPH phrase sentences:  2
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['there tolstoy ']
# Top phrases by frequency:
# there tolstoy  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['there tolstoy ']
# Top phrases by frequency:
# there tolstoy  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['only open ']
# Top phrases by frequency:
# only open  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['only open ']
# Top phrases by frequency:
# only open  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['too clumsy ']
# Top phrases by frequency:
# too clumsy  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['too clumsy ']
# Top phrases by frequency:
# too clumsy  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['not sophomoric ']
# Top phrases by frequency:
# not sophomoric  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['not sophomoric ']
# Top phrases by frequency:
# not sophomoric  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['very light ']
# Top phrases by frequency:
# very light  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['very light ']
# Top phrases by frequency:
# very light  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['simply tired ']
# Top phrases by frequency:
# simply tired  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['simply tired ']
# Top phrases by frequency:
# simply tired  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['eerily accurate ']
# Top phrases by frequency:
# eerily accurate  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['eerily accurate ']
# Top phrases by frequency:
# eerily accurate  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['perfectly entertaining ']
# Top phrases by frequency:
# perfectly entertaining  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['perfectly entertaining ']
# Top phrases by frequency:
# perfectly entertaining  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['rather convoluted ']
# Top phrases by frequency:
# rather convoluted  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['rather convoluted ']
# Top phrases by frequency:
# rather convoluted  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['deeply unsettling ']
# Top phrases by frequency:
# deeply unsettling  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['deeply unsettling ']
# Top phrases by frequency:
# deeply unsettling  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['barely defensible ']
# Top phrases by frequency:
# barely defensible  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['barely defensible ']
# Top phrases by frequency:
# barely defensible  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['emotionally scattered ']
# Top phrases by frequency:
# emotionally scattered  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['emotionally scattered ']
# Top phrases by frequency:
# emotionally scattered  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['otherwise dull ']
# Top phrases by frequency:
# otherwise dull  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['otherwise dull ']
# Top phrases by frequency:
# otherwise dull  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['far too much ']
# Top phrases by frequency:
# far too much  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['far too much ']
# Top phrases by frequency:
# far too much  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['ultimately silly ']
# Top phrases by frequency:
# ultimately silly  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['ultimately silly ']
# Top phrases by frequency:
# ultimately silly  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['horrendously amateurish ', 'plainly dull ', "n't incomprehensible "]
# Top phrases by frequency:
# horrendously amateurish  1
# plainly dull  1
# n't incomprehensible  1
# Length of ADJPH phrase sentences:  3
# phrases:  ['horrendously amateurish ', 'plainly dull ', "n't incomprehensible "]
# Top phrases by frequency:
# horrendously amateurish  1
# plainly dull  1
# n't incomprehensible  1
# Length of ADJPH phrase sentences:  3
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['awkwardly contrived ']
# Top phrases by frequency:
# awkwardly contrived  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['awkwardly contrived ']
# Top phrases by frequency:
# awkwardly contrived  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['so much ']
# Top phrases by frequency:
# so much  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['so much ']
# Top phrases by frequency:
# so much  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['very graphic ']
# Top phrases by frequency:
# very graphic  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['very graphic ']
# Top phrases by frequency:
# very graphic  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['more sophisticated ']
# Top phrases by frequency:
# more sophisticated  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['more sophisticated ']
# Top phrases by frequency:
# more sophisticated  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['probably more fun ']
# Top phrases by frequency:
# probably more fun  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['probably more fun ']
# Top phrases by frequency:
# probably more fun  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['mighty hard ']
# Top phrases by frequency:
# mighty hard  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['mighty hard ']
# Top phrases by frequency:
# mighty hard  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['so nice ']
# Top phrases by frequency:
# so nice  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['so nice ']
# Top phrases by frequency:
# so nice  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['even more predictable ']
# Top phrases by frequency:
# even more predictable  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['even more predictable ']
# Top phrases by frequency:
# even more predictable  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['so bad ']
# Top phrases by frequency:
# so bad  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['so bad ']
# Top phrases by frequency:
# so bad  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['more confused ', 'less interesting ']
# Top phrases by frequency:
# more confused  1
# less interesting  1
# Length of ADJPH phrase sentences:  2
# phrases:  ['more confused ', 'less interesting ']
# Top phrases by frequency:
# more confused  1
# less interesting  1
# Length of ADJPH phrase sentences:  2
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['very bad ']
# Top phrases by frequency:
# very bad  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['very bad ']
# Top phrases by frequency:
# very bad  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['defiantly retro ']
# Top phrases by frequency:
# defiantly retro  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['defiantly retro ']
# Top phrases by frequency:
# defiantly retro  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['most wondrously gifted ']
# Top phrases by frequency:
# most wondrously gifted  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['most wondrously gifted ']
# Top phrases by frequency:
# most wondrously gifted  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['so many ']
# Top phrases by frequency:
# so many  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['so many ']
# Top phrases by frequency:
# so many  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['very good ']
# Top phrases by frequency:
# very good  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['very good ']
# Top phrases by frequency:
# very good  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['more enjoyable ', 'fairly basic ']
# Top phrases by frequency:
# more enjoyable  1
# fairly basic  1
# Length of ADJPH phrase sentences:  2
# phrases:  ['more enjoyable ', 'fairly basic ']
# Top phrases by frequency:
# more enjoyable  1
# fairly basic  1
# Length of ADJPH phrase sentences:  2
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['beautifully sung ']
# Top phrases by frequency:
# beautifully sung  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['beautifully sung ']
# Top phrases by frequency:
# beautifully sung  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['almost constant ']
# Top phrases by frequency:
# almost constant  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['almost constant ']
# Top phrases by frequency:
# almost constant  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['otherwise bleak ']
# Top phrases by frequency:
# otherwise bleak  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['otherwise bleak ']
# Top phrases by frequency:
# otherwise bleak  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['genuinely unnerving ']
# Top phrases by frequency:
# genuinely unnerving  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['genuinely unnerving ']
# Top phrases by frequency:
# genuinely unnerving  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['increasingly diverse ']
# Top phrases by frequency:
# increasingly diverse  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['increasingly diverse ']
# Top phrases by frequency:
# increasingly diverse  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['often surprising ']
# Top phrases by frequency:
# often surprising  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['often surprising ']
# Top phrases by frequency:
# often surprising  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['largely bogus ']
# Top phrases by frequency:
# largely bogus  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['largely bogus ']
# Top phrases by frequency:
# largely bogus  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['really special ']
# Top phrases by frequency:
# really special  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['really special ']
# Top phrases by frequency:
# really special  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['too much ']
# Top phrases by frequency:
# too much  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['too much ']
# Top phrases by frequency:
# too much  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['more psychotic ']
# Top phrases by frequency:
# more psychotic  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['more psychotic ']
# Top phrases by frequency:
# more psychotic  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['mildly enjoyable ', 'much better ']
# Top phrases by frequency:
# mildly enjoyable  1
# much better  1
# Length of ADJPH phrase sentences:  2
# phrases:  ['mildly enjoyable ', 'much better ']
# Top phrases by frequency:
# mildly enjoyable  1
# much better  1
# Length of ADJPH phrase sentences:  2
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ["n't as sharp "]
# Top phrases by frequency:
# n't as sharp  1
# Length of ADJPH phrase sentences:  1
# phrases:  ["n't as sharp "]
# Top phrases by frequency:
# n't as sharp  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['rather cold-blooded ']
# Top phrases by frequency:
# rather cold-blooded  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['rather cold-blooded ']
# Top phrases by frequency:
# rather cold-blooded  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['rather thinly-conceived ']
# Top phrases by frequency:
# rather thinly-conceived  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['rather thinly-conceived ']
# Top phrases by frequency:
# rather thinly-conceived  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['often inspiring ']
# Top phrases by frequency:
# often inspiring  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['often inspiring ']
# Top phrases by frequency:
# often inspiring  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['not mean-spirited ']
# Top phrases by frequency:
# not mean-spirited  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['not mean-spirited ']
# Top phrases by frequency:
# not mean-spirited  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['just enough freshness ']
# Top phrases by frequency:
# just enough freshness  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['just enough freshness ']
# Top phrases by frequency:
# just enough freshness  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['gorgeously atmospheric ']
# Top phrases by frequency:
# gorgeously atmospheric  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['gorgeously atmospheric ']
# Top phrases by frequency:
# gorgeously atmospheric  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['mostly undeterminable ']
# Top phrases by frequency:
# mostly undeterminable  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['mostly undeterminable ']
# Top phrases by frequency:
# mostly undeterminable  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['so intimate ', 'psychologically self-revealing ']
# Top phrases by frequency:
# so intimate  1
# psychologically self-revealing  1
# Length of ADJPH phrase sentences:  2
# phrases:  ['so intimate ', 'psychologically self-revealing ']
# Top phrases by frequency:
# so intimate  1
# psychologically self-revealing  1
# Length of ADJPH phrase sentences:  2
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['disappointingly thin ', 'surprisingly little ']
# Top phrases by frequency:
# disappointingly thin  1
# surprisingly little  1
# Length of ADJPH phrase sentences:  2
# phrases:  ['disappointingly thin ', 'surprisingly little ']
# Top phrases by frequency:
# disappointingly thin  1
# surprisingly little  1
# Length of ADJPH phrase sentences:  2
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['breathtakingly creative ']
# Top phrases by frequency:
# breathtakingly creative  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['breathtakingly creative ']
# Top phrases by frequency:
# breathtakingly creative  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['so original ']
# Top phrases by frequency:
# so original  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['so original ']
# Top phrases by frequency:
# so original  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['entirely foreign ']
# Top phrases by frequency:
# entirely foreign  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['entirely foreign ']
# Top phrases by frequency:
# entirely foreign  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['not worth ']
# Top phrases by frequency:
# not worth  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['not worth ']
# Top phrases by frequency:
# not worth  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['visually atrocious ', 'often downright ']
# Top phrases by frequency:
# visually atrocious  1
# often downright  1
# Length of ADJPH phrase sentences:  2
# phrases:  ['visually atrocious ', 'often downright ']
# Top phrases by frequency:
# visually atrocious  1
# often downright  1
# Length of ADJPH phrase sentences:  2
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['most highly-praised ']
# Top phrases by frequency:
# most highly-praised  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['most highly-praised ']
# Top phrases by frequency:
# most highly-praised  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['always watchable ', 'yet hardly memorable ']
# Top phrases by frequency:
# always watchable  1
# yet hardly memorable  1
# Length of ADJPH phrase sentences:  2
# phrases:  ['always watchable ', 'yet hardly memorable ']
# Top phrases by frequency:
# always watchable  1
# yet hardly memorable  1
# Length of ADJPH phrase sentences:  2
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['more inexplicable ', 'more crassly reductive ']
# Top phrases by frequency:
# more inexplicable  1
# more crassly reductive  1
# Length of ADJPH phrase sentences:  2
# phrases:  ['more inexplicable ', 'more crassly reductive ']
# Top phrases by frequency:
# more inexplicable  1
# more crassly reductive  1
# Length of ADJPH phrase sentences:  2
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['too clever ']
# Top phrases by frequency:
# too clever  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['too clever ']
# Top phrases by frequency:
# too clever  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['not as good ']
# Top phrases by frequency:
# not as good  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['not as good ']
# Top phrases by frequency:
# not as good  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ["n't funny "]
# Top phrases by frequency:
# n't funny  1
# Length of ADJPH phrase sentences:  1
# phrases:  ["n't funny "]
# Top phrases by frequency:
# n't funny  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['desperately ingratiating ']
# Top phrases by frequency:
# desperately ingratiating  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['desperately ingratiating ']
# Top phrases by frequency:
# desperately ingratiating  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['even easier ']
# Top phrases by frequency:
# even easier  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['even easier ']
# Top phrases by frequency:
# even easier  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['terribly funny ']
# Top phrases by frequency:
# terribly funny  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['terribly funny ']
# Top phrases by frequency:
# terribly funny  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['pitifully few ']
# Top phrases by frequency:
# pitifully few  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['pitifully few ']
# Top phrases by frequency:
# pitifully few  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['only hairier ']
# Top phrases by frequency:
# only hairier  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['only hairier ']
# Top phrases by frequency:
# only hairier  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['most multilayered ']
# Top phrases by frequency:
# most multilayered  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['most multilayered ']
# Top phrases by frequency:
# most multilayered  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# ...
# michelle gellar  1
# Length of ADJPH phrase sentences:  1
# phrases:  ["n't much "]
# Top phrases by frequency:
# n't much  1
# Length of ADJPH phrase sentences:  1
# phrases:  ["n't much "]
# Top phrases by frequency:
# n't much  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['more fun ', 'rather clever ']
# Top phrases by frequency:
# more fun  1
# rather clever  1
# Length of ADJPH phrase sentences:  2
# phrases:  ['more fun ', 'rather clever ']
# Top phrases by frequency:
# more fun  1
# rather clever  1
# Length of ADJPH phrase sentences:  2
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['only makeup-deep ']
# Top phrases by frequency:
# only makeup-deep  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['only makeup-deep ']
# Top phrases by frequency:
# only makeup-deep  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['more relevant ', 'once intimate ']
# Top phrases by frequency:
# more relevant  1
# once intimate  1
# Length of ADJPH phrase sentences:  2
# phrases:  ['more relevant ', 'once intimate ']
# Top phrases by frequency:
# more relevant  1
# once intimate  1
# Length of ADJPH phrase sentences:  2
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['very charming ']
# Top phrases by frequency:
# very charming  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['very charming ']
# Top phrases by frequency:
# very charming  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['ultimately pointless ']
# Top phrases by frequency:
# ultimately pointless  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['ultimately pointless ']
# Top phrases by frequency:
# ultimately pointless  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['markedly inactive ']
# Top phrases by frequency:
# markedly inactive  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['markedly inactive ']
# Top phrases by frequency:
# markedly inactive  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['somewhat satisfying ']
# Top phrases by frequency:
# somewhat satisfying  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['somewhat satisfying ']
# Top phrases by frequency:
# somewhat satisfying  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['wonderfully speculative ', 'rather slow ']
# Top phrases by frequency:
# wonderfully speculative  1
# rather slow  1
# Length of ADJPH phrase sentences:  2
# phrases:  ['wonderfully speculative ', 'rather slow ']
# Top phrases by frequency:
# wonderfully speculative  1
# rather slow  1
# Length of ADJPH phrase sentences:  2
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['nonchalantly freaky ', 'most unpredictable ']
# Top phrases by frequency:
# nonchalantly freaky  1
# most unpredictable  1
# Length of ADJPH phrase sentences:  2
# phrases:  ['nonchalantly freaky ', 'most unpredictable ']
# Top phrases by frequency:
# nonchalantly freaky  1
# most unpredictable  1
# Length of ADJPH phrase sentences:  2
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['too much ']
# Top phrases by frequency:
# too much  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['too much ']
# Top phrases by frequency:
# too much  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['pretty much ']
# Top phrases by frequency:
# pretty much  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['pretty much ']
# Top phrases by frequency:
# pretty much  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['staggeringly dreadful ']
# Top phrases by frequency:
# staggeringly dreadful  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['staggeringly dreadful ']
# Top phrases by frequency:
# staggeringly dreadful  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['so much ']
# Top phrases by frequency:
# so much  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['so much ']
# Top phrases by frequency:
# so much  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['terminally cute ']
# Top phrases by frequency:
# terminally cute  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['terminally cute ']
# Top phrases by frequency:
# terminally cute  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['consistently surprising ', 'so dumb ']
# Top phrases by frequency:
# consistently surprising  1
# so dumb  1
# Length of ADJPH phrase sentences:  2
# phrases:  ['consistently surprising ', 'so dumb ']
# Top phrases by frequency:
# consistently surprising  1
# so dumb  1
# Length of ADJPH phrase sentences:  2
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['positively leaden ']
# Top phrases by frequency:
# positively leaden  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['positively leaden ']
# Top phrases by frequency:
# positively leaden  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['more fascinating ', 'most high-concept ']
# Top phrases by frequency:
# more fascinating  1
# most high-concept  1
# Length of ADJPH phrase sentences:  2
# phrases:  ['more fascinating ', 'most high-concept ']
# Top phrases by frequency:
# more fascinating  1
# most high-concept  1
# Length of ADJPH phrase sentences:  2
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['just as much ']
# Top phrases by frequency:
# just as much  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['just as much ']
# Top phrases by frequency:
# just as much  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['always welcome ']
# Top phrases by frequency:
# always welcome  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['always welcome ']
# Top phrases by frequency:
# always welcome  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['more interesting ']
# Top phrases by frequency:
# more interesting  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['more interesting ']
# Top phrases by frequency:
# more interesting  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['woefully pretentious ']
# Top phrases by frequency:
# woefully pretentious  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['woefully pretentious ']
# Top phrases by frequency:
# woefully pretentious  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['abundantly clear ']
# Top phrases by frequency:
# abundantly clear  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['abundantly clear ']
# Top phrases by frequency:
# abundantly clear  1
# Length of ADJPH phrase sentences:  1
# phrases:  ["n't entirely infantile "]
# Top phrases by frequency:
# n't entirely infantile  1
# Length of ADJPH phrase sentences:  1
# phrases:  ["n't entirely infantile "]
# Top phrases by frequency:
# n't entirely infantile  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['wondrously creative ']
# Top phrases by frequency:
# wondrously creative  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['wondrously creative ']
# Top phrases by frequency:
# wondrously creative  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['down easy ']
# Top phrases by frequency:
# down easy  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['down easy ']
# Top phrases by frequency:
# down easy  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['certainly beautiful ', 'not very informative ', 'more challenging ']
# Top phrases by frequency:
# certainly beautiful  1
# not very informative  1
# more challenging  1
# Length of ADJPH phrase sentences:  3
# phrases:  ['certainly beautiful ', 'not very informative ', 'more challenging ']
# Top phrases by frequency:
# certainly beautiful  1
# not very informative  1
# more challenging  1
# Length of ADJPH phrase sentences:  3
# phrases:  ['mike leigh ']
# Top phrases by frequency:
# mike leigh  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['mike leigh ']
# Top phrases by frequency:
# mike leigh  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['almost visceral ']
# Top phrases by frequency:
# almost visceral  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['almost visceral ']
# Top phrases by frequency:
# almost visceral  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['particularly memorable ']
# Top phrases by frequency:
# particularly memorable  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['particularly memorable ']
# Top phrases by frequency:
# particularly memorable  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['as exciting ']
# Top phrases by frequency:
# as exciting  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['as exciting ']
# Top phrases by frequency:
# as exciting  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['reasonably entertaining ']
# Top phrases by frequency:
# reasonably entertaining  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['reasonably entertaining ']
# Top phrases by frequency:
# reasonably entertaining  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['rather sad ']
# Top phrases by frequency:
# rather sad  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['rather sad ']
# Top phrases by frequency:
# rather sad  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['almost perpetually wasted ']
# Top phrases by frequency:
# almost perpetually wasted  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['almost perpetually wasted ']
# Top phrases by frequency:
# almost perpetually wasted  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['barely adequate ']
# Top phrases by frequency:
# barely adequate  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['barely adequate ']
# Top phrases by frequency:
# barely adequate  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['very good ']
# Top phrases by frequency:
# very good  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['very good ']
# Top phrases by frequency:
# very good  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['more compelling ']
# Top phrases by frequency:
# more compelling  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['more compelling ']
# Top phrases by frequency:
# more compelling  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['laughingly enjoyable ']
# Top phrases by frequency:
# laughingly enjoyable  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['laughingly enjoyable ']
# Top phrases by frequency:
# laughingly enjoyable  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  ['excruciatingly tedious ']
# Top phrases by frequency:
# excruciatingly tedious  1
# Length of ADJPH phrase sentences:  1
# phrases:  ['excruciatingly tedious ']
# Top phrases by frequency:
# excruciatingly tedious  1
# Length of ADJPH phrase sentences:  1
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0
# phrases:  []
# Top phrases by frequency:
# Length of ADJPH phrase sentences:  0

# %%
# see how adjective phrase compares to the whole review
for index in range(train_additional_cols_num_rows):
    if train_additional_cols['adjph'][index]!="no ADJPH phrases detected":
        print(index)
        print(train_additional_cols['Phrase'][index], train_additional_cols['Sentiment'][index], train_additional_cols['adjph'][index])
        print('------next item-----------')

# %% [markdown]
# This function will print top 50 tags and their frequency based on POS tag list provided provided ie we can supply adjective POS token tree and tagged text.

# %%
def get_top50_pos_tokens(pos_list, taggedtext):
    pos_tokens = []
    freq_table = PrettyTable(['word', 'frequency'])
    for sentence in taggedtext:
        for word, pos in sentence:
            if pos in pos_list:
                if len(word)>1:
                    pos_tokens.append(word)
    freq_pos = FreqDist(pos_tokens)
    for word, freq in freq_pos.most_common(50):
        freq_table.add_row([word, freq])
    print(freq_table)

# %% [markdown]
# ### Next steps

# %% [markdown]
# - 1. We can incorporate frequency you worked on
# - 2. Add adverb, verb, noun phrase analysis (rules already set up, I did adjective phrases as an example)
# - 3. Run Naive Bayes and maybe another model to predict
